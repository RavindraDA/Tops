# %% [markdown]
# 1) Types of Applications.
# Desktop
# Web
# Mobile
# Enterprise
# Scientific
#
# (2) What is programing?
#  Programming is writing instructions for a computer to perform tasks.
#
# (3) What is Python?
#  Python is a high-level, easy programming language used for web, AI, and data.

# %%
# (4) # Take input from the user
num = float(input("Enter a number: "))


if num > 0:
    print("positive")
elif num < 0:
    print("negative")
else:
    print("number is zero")

# %%
# (5) Write a Python program to get the Factorial number of given numbers. 
# Take input from the user
num = int(input("Enter a number: "))

factorial = 1


if num < 0:
    print("wrong number")
elif num == 0:
    print("Factorial of 0 is 1.")
else:
    for i in range(1, num + 1):
        factorial *= i
    print(f"Factorial of {num} is {factorial}.")

# %%
# (6)Write a Python program to get the Fibonacci series of given range. 
# Take input from the user
n = int(input("Enter the number of terms: "))


a, b = 0, 1

print("Fibonacci series:")

for i in range(n):
    print(a, end=" ")
    a, b = b, a + b

# %% [markdown]
# (7)How memory is managed in Python?
# Python uses automatic memory management and garbage collection.
#
# (8) What is the purpose continuing statement in python?
# continue skips current loop iteration and moves to next.

# %%
# (9)  Write python program that swap two number with temp variable and without temp variable.

a, b = 5, 10
temp = a
a = b
b = temp
print("a =", a, "b =", b)
# Out:
# a = 10 b = 5

# %%
# (10) Write a Python program to find whether a given number is even or odd, print out an appropriate message to the user. 
  
n = int(input("Enter number: "))
if n % 2 == 0:
   print("Even")
else:
    print("Odd")
# Out:
# Odd

# %%
# (11) Write a Python program to test whether a passed letter is a vowel or not.
 
ch = input("Enter character: ")
if ch in "aeiouAEIOU":
    print("Vowel")
else:
    print("Not Vowel")
# Out:
# Vowel

# %%
# (12) Write a Python program to sum of three given integers. However, if two values are equal sum will be zero. 
# Take input from the user
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))


if a == b or b == c or a == c:
    result = 0
else:
    result = a + b + c

print("Result:", result)

# %%
# (13) Write a Python program that will return true if the two given integer values are equal or their sum or difference is 5.


a = int(input("Enter first number: "))
b = int(input("Enter second number: "))


if a == b or (a + b) == 5 or abs(a - b) == 5:
    print(True)
else:
    print(False)

# %%
# (14)Write a python program to sum of the first n positive integers.

n = int(input("Enter a positive integer: "))

if n < 0:
    print("Please enter a positive integer.")
else:
    total = 0
    for i in range(1, n + 1):
        total += i
    print(f"Sum of first {n} positive integers is {total}.")

# %%
# (15)Write a Python program to calculate the length of a string. 


s = input("Enter string: ")
print("Length =", len(s))
# Out:
# Length = 2

# %% [markdown]
# (17)What are negative indexes and why are they used?
#
# Negative indexes start from -1
# Used to access elements from the end of string/list
#
# Example:
#
# s = "hello"
# print(s[-1])

# %%
# (18) Write a Python program to count occurrences of a substring in a string. 

s = input("Enter string: ")
sub = input("Enter substring: ")

print("Count =", s.count(sub))
# Out:
# Count = 0

# %%
# (19)  Write a Python program to count the occurrences of each word in a   given sentence 
s = input("Enter sentence: ")
words = s.split()
d = {}

for w in words:
    if w in d:
        d[w] += 1
    else:
        d[w] = 1

print(d)
# Out:
# {'23': 1}

# %%
# (20) Write a Python program to get a single string from two given strings,separated by a space and swap the first two characters of each string. 

s1 = input("Enter first string: ")
s2 = input("Enter second string: ")

new_s1 = s2[:2] + s1[2:]
new_s2 = s1[:2] + s2[2:]

print(new_s1, new_s2)
# Out:
# 45 23

# %%
# (21) Write a Python program to add 'in' at the end of a given string (length should be at least 3). If the given string already ends with 'ing' then add 'ly' instead if the string length of the given string is less than 3, leave it unchanged.

s = input("Enter string: ")

if len(s) < 3:
    print(s)
elif s.endswith("ing"):
    print(s + "ly")
else:
    print(s + "in")
# Out:
# 12

# %%
# (22) Write a Python function to reverses a string if its length is a multiple or 4

def reverse_string(s):
    if len(s) % 4 == 0:
        return s[::-1]
    return s

print(reverse_string(input("Enter string: ")))
# Out:
# 34

# %%
# (23)Write a Python program to get a string made of the first 2 and the last 2 chars from a given a string. If the string length is less than 2, return instead of the empty string. 
s = input("Enter string: ")

if len(s) < 2:
    print("Empty string")
else:
    print(s[:2] + s[-2:])
# Out:
# 4545

# %%
# (24) Write a Python function to insert a string in the middle of a string. 
def insert_middle(s, insert):
    mid = len(s) // 2
    return s[:mid] + insert + s[mid:]

print(insert_middle("hello", "X"))
# Out:
# heXllo

# %%
# (25) What is List? How will you reverse a list? 
l = [1, 2, 3, 4]
l.reverse()
print(l)
# Out:
# [4, 3, 2, 1]

# %%
# (26)  How will you remove last object from a list? 
l = [1, 2, 3]
l.pop()
print(l)
# Out:
# [1, 2]

# %%
# (27) Suppose list1 is [2, 33, 222, 14, and 25], what is list1 [-1]?
list1 = [2, 33, 222, 14, 25]
print(list1[-1])
# Out:
# 25

# %%
# (28) Differentiate between append () and extend () methods?

l = [1, 2]
l.append([3, 4])
print(l)

l = [1, 2]
l.extend([3, 4])
print(l)

# %%
# (29) Write a Python function to get the largest number, smallest num and sum of all from a list. 

def list_operations(l):
    print("Largest =", max(l))
    print("Smallest =", min(l))
    print("Sum =", sum(l))

l = [10, 5, 20, 8]
list_operations(l)

# %%
# (30) How will you compare two lists? 

l1 = [1, 2, 3]
l2 = [1, 2, 3]

if l1 == l2:
    print("Lists are equal")
else:
    print("Lists are not equal")

# %%
# (31) 31) Write a Python program to count the number of strings where the string length is 2 or more and the first and last character are same from a given list of strings.

l = ["abc", "aba", "xyz", "aa", "x"]
count = 0

for s in l:
    if len(s) >= 2 and s[0] == s[-1]:
        count += 1

print("Count =", count)

# %%
# (32))Write a Python program to remove duplicates from a list. 
l = [1, 2, 2, 3, 4, 4]
l = list(set(l))
print(l)

# %%
# (33) Write a Python program to check a list is empty or not

l = []

if not l:
    print("List is empty")
else:
    print("Not empty")

# %%
# (34) Write a Python function that takes two lists and returns true if they have at least one common member. 

l1 = [1, 2, 3]
l2 = [3, 4, 5]

print(any(x in l2 for x in l1))

# %%
# (35)  Write a Python program to generate and print a list of first and last 5 elements where the values are square of numbers between 1 and 30. 
l = [x**2 for x in range(1, 31)]
print(l[:5])
print(l[-5:])

# %%
# (36) Write a Python function that takes a list and returns a new list with unique elements of the first list
def unique_list(l):
  return list(set(l))

print(unique_list([1,2,2,3,4]))

# %%
# (37) Write a Python program to convert a list of characters into a string. 

l = ['h','e','l','l','o']
s = ''.join(l)
print(s)

# %%
# (38) Write a Python program to select an item randomly from a list. 
import random

l = [1, 2, 3, 4]
print(random.choice(l))

# %%
# (39) Write a Python program to find the second smallest number in a list.

l = [5, 1, 4, 2]
l.sort()
print(l[1])

# %%
# (40) Write a Python program to get unique values from a list

l = [1,2,2,3,3,4]
print(list(set(l)))

# %%
# (41)  Write a Python program to check whether a list contains a sub list 
l = [1, 2, 3, 4, 5]
sub = [3, 4]

for i in range(len(l) - len(sub) + 1):
    if l[i:i+len(sub)] == sub:
        print("Sublist found")
        break
else:
    print("Not found")

# %%
# (42) Write a Python program to split a list into different variables. 

l = [10, 20, 30]
a, b, c = l

print(a, b, c)

# %% [markdown]
# 43) What is tuple? Difference between list and tuple.
# A tuple is an ordered, immutable collection of elements in Python (written using ()).
# list- muttable
# tuple-immutable

# %%
#44)Write a Python program to create a tuple with different data types.
my_tuple = (10, "Hello", 3.14, True)
print(my_tuple)

#45)Write a Python program to unzip a list of tuples into individual lists.
data = [(1, 'a'), (2, 'b'), (3, 'c')]

nums, chars = zip(*data)

print(list(nums))
print(list(chars)) 

#46)Write a Python program to convert a list of tuples into a dictionary.
data = [('a', 1), ('b', 2), ('c', 3)]

my_dict = dict(data)
print(my_dict)

#47)How will you create a dictionary using tuples in python?
keys = ('a', 'b', 'c')
values = (1, 2, 3)

my_dict = dict(zip(keys, values))
print(my_dict)

#48)Write a Python script to sort (ascending and descending) a dictionary by value.
data = {'a': 3, 'b': 1, 'c': 2}

# Ascending
asc = dict(sorted(data.items(), key=lambda x: x[1]))

# Descending
desc = dict(sorted(data.items(), key=lambda x: x[1], reverse=True))

print("Ascending:", asc)
print("Descending:", desc)

#49)Write a Python script to concatenate following dictionaries to createa new one.
d1 = {'a': 1}
d2 = {'b': 2}
d3 = {'c': 3}

new_dict = {}
for d in (d1, d2, d3):
    new_dict.update(d)

print(new_dict)

#50)Write a Python script to check if a given key already exists in a dictionary.
data = {'a': 1, 'b': 2}

key = 'a'

if key in data:
    print("Key exists")
else:
    print("Key does not exist")

#51)How Do You Traverse Through a Dictionary Object in Python?
data = {'a': 1, 'b': 2, 'c': 3}

# Keys
for key in data:
    print(key)

# Values
for value in data.values():
    print(value)

# Key-value pairs
for key, value in data.items():
    print(key, value)

#52)How Do You Check the Presence of a Key in A Dictionary?
data = {'x': 10, 'y': 20}

print('x' in data) 

#53)Write a Python script to print a dictionary where the keys are numbers between 1 and 15.
my_dict = {x: x*x for x in range(1, 16)}
print(my_dict)

#54)Write a Python program to check multiple keys exists in a dictionary
data = {'a': 1, 'b': 2, 'c': 3}
keys = ['a', 'b']

if all(k in data for k in keys):
    print("All keys exist")
else:
    print("Some keys are missing")

#55)Write a Python script to merge two Python dictionaries
d1 = {'a': 1}
d2 = {'b': 2}

merged = {**d1, **d2}
print(merged)

#56)Write a Python program to map two lists into a dictionary
# Sample output: Counter ({'a': 400, 'b': 400,’d’: 400, 'c': 300}). 
keys = ['a', 'b', 'c', 'd']
values = [400, 400, 300, 400]

result = dict(zip(keys, values))
print(result)

#57)Write a Python program to find the highest 3 values in a dictionary
def highest_three_values(d):
    values = sorted(d.values(), reverse=True)
    return values[:3]

# Example
data = {'a': 10, 'b': 50, 'c': 30, 'd': 20}
print(highest_three_values(data))

#58)Write a Python program to combine values in python list of dictionaries.

#Sample data: [{'item': 'item1', 'amount': 400}, {'item': 'item2', 'amount':
#300}, o {'item': 'item1', 'amount': 750}]
#Expected Output:
# Counter ({'item1': 1150, 'item2': 300})

from collections import Counter

data = [
    {'item': 'item1', 'amount': 400},
    {'item': 'item2', 'amount': 300},
    {'item': 'item1', 'amount': 750}
]

result = Counter()

for d in data:
    result[d['item']] += d['amount']

print(result)

#59)Write a Python program to create a dictionary from a string.
#Note: Track the count of the letters from the string.


#60)Sample string:
# 'w3resource' Expected output:
#• {'3': 1,’s’: 1, 'r': 2, 'u': 1, 'w': 1, 'c': 1, 'e': 2, 'o': 1}

#61)Write a Python function to calculate the factorial of a number (a
#nonnegative integer)
def factorial(n):
    if n < 0:
        return "Invalid input"
    elif n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)

# Example
print(factorial(5))

#62)Write a Python function to check whether a number is in a given range
def is_in_range(num, start, end):
    return start <= num <= end

# Example
print(is_in_range(5, 1, 10))

#63)Write a Python function to check whether a number is perfect or not.
def is_perfect(n):
    if n <= 0:
        return False
    sum_divisors = sum(i for i in range(1, n) if n % i == 0)
    return sum_divisors == n

# Example
print(is_perfect(6))  # True

#64)Write a Python function that checks whether a passed string is
#palindrome or not 
def is_palindrome(s):
    return s == s[::-1]

# Example
print(is_palindrome("madam"))  # True
# Out:
# (10, 'Hello', 3.14, True)
# [1, 2, 3]
# ['a', 'b', 'c']
# {'a': 1, 'b': 2, 'c': 3}
# {'a': 1, 'b': 2, 'c': 3}
# Ascending: {'b': 1, 'c': 2, 'a': 3}
# Descending: {'a': 3, 'c': 2, 'b': 1}
# {'a': 1, 'b': 2, 'c': 3}
# Key exists
# a
# b
# c
# 1
# 2
# 3
# a 1
# b 2
# c 3
# True
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}
# All keys exist
# {'a': 1, 'b': 2}
# {'a': 400, 'b': 400, 'c': 300, 'd': 400}
# [50, 30, 20]

# %%
#66) How can you pick a random item from a list or tuple?
import random
print(random.choice([1,2,3]))
# Out:
# 1

# %%
# (67) How can you pick a random item from a range? 

import random
print(random.choice(range(1,10)))
# Out:
# 2

# %%
# (68) How can you get a random number in python? 

import random
print(random.randint(1,100))
# Out:
# 17

# %%
# (69) How will you set the starting value in generating random numbers?

import random
random.seed(1)
print(random.randint(1,100))
# Out:
# 18

# %%
#(70) How will you randomize the items of a list in place? 

import random
l = [1,2,3,4]
random.shuffle(l)
print(l)

# %% [markdown]
# 71) What is File function in python? What are keywords  to create and write file
#
# Used to read/write files
# Keywords: "r", "w", "a"

# %%
# (72) Write a Python program to read an entire text file. 


f = open(r"C:\Users\DELL\OneDrive\New Folder\python\sample","r")
print(f.read())
f.close()
# Out:
# nothingbakachiki

# %%
# (73) Write a Python program to append text to a file and display the text. 
# Append text
with open(r"C:\Users\DELL\OneDrive\New Folder\python\sample", "a") as f:
    f.write("Hello\n")

# Read and display file content
with open(r"C:\Users\DELL\OneDrive\New Folder\python\sample", "r") as f:
    print(f.read())
# Out:
# nothingbakachiki
# Hello

# %%
# (74) Write a Python program to read first n lines of a file. 

n = 2  # number of lines to read

with open(r"C:\Users\DELL\OneDrive\New Folder\python\sample", "r") as f:
    for i in range(n):
        print(f.readline(), end="")
# Out:
# nothingbakachiki
# Hello

# %%
# (75) Write a Python program to read last n lines of a file. 

n = 2  # number of last lines

with open(r"C:\Users\DELL\OneDrive\New Folder\python\sample", "r") as f:
    lines = f.readlines()

print("".join(lines[-n:]))
# Out:
# nothingbakachiki
# Hello

# %%
# (76) Write a Python program to read a file line by line and store it into a list 

with open(r"C:\Users\DELL\OneDrive\New Folder\python\sample", "r") as f:
    l = f.readlines()
print(l)
# Out:
# ['nothingbakachiki\n', 'Hello\n']

# %%
# (77) Write a Python program to read a file line by line store it into a variable. 

with open(r"C:\Users\DELL\OneDrive\New Folder\python\sample", "r") as f:
    data = f.read()
print(data)
# Out:
# nothingbakachiki
# Hello

# %%
# (78) Write a python program to find the longest words

s = "I love python programming"
words = s.split()
print(max(words, key=len))
# Out:
# programming

# %%
# (79) Write a Python program to count the number of lines in a text file. 

with open(r"C:\Users\DELL\OneDrive\New Folder\python\sample", "r") as f:
 print(len(f.readlines()))
# Out:
# 2

# %%
# (80) Write a Python program to count the frequency of words in a file. 

from collections import Counter

with open(r"C:\Users\DELL\OneDrive\New Folder\python\sample", "r") as f:
    words = f.read().split()

print(Counter(words))
# Out:
# Counter({'nothingbakachiki': 1, 'Hello': 1})

# %%
# (81) Write a Python program to write a list to a file. 

l = ["a","b","c"]
with open(r"C:\Users\DELL\OneDrive\New Folder\python\sample", "r""w") as f:
    for i in l:
        f.write(i+"\n")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[19], line 6
#       4 with open(r"C:\Users\DELL\OneDrive\New Folder\python\sample", "r") as f:
#       5     for i in l:
# ----> 6         f.write(i+"\n")
#
# UnsupportedOperation: not writable

# %%
# (82))Write a Python program to write a list to a file. 

with open("file.txt") as f1, open("new.txt","w") as f2:
    f2.write(f1.read())

# %% [markdown]
# 83) Write a Python program to copy the contents of a file to another file
#
# Used to handle runtime errors
# Error = problem in program

# %%
# (84) Explain Exception handling? What is an Error in Python? 

try:
    x = int("abc")
except ValueError:
    print("Value error")
except:
    print("Other error")

# %% [markdown]
# 85) When will the else part of try-except-else be executed?
#
# Runs only if no exception occurs

# %%
# (86) Can one block of except statements handle multiple exception? 

try:
    x = int("abc")
except (ValueError, TypeError):
    print("Handled")

# %%
# (87)  When is the finally block executed? 
#The finally block is always executed, no matter what happens in the program.

#It runs when
# If no exception occurs
# If an exception occurs
# Even if there is a return statement
try:
    print("Inside try block")
    x = 10 / 2
except:
    print("Error occurred")
finally:
    print("Finally block executed")

# %%
# (88) What happens when „1‟== 1 is executed?

#'1' is a string
#  1 is an integer

# Python does not convert automatically here.

# Example:
print('1' == 1)

# %%
# (89) How Do You Handle Exceptions with Try/Except/Finally in Python? 

#try - risky code
#except - handle error
#finally - always runs
#  Example:
try:
    num = int(input("Enter a number: "))
    result = 10 / num
    print("Result:", result)

except ZeroDivisionError:
    print("Cannot divide by zero!")

except ValueError:
    print("Invalid input!")

finally:
    print("Program finished")

# %%
# (90)  Write python program that user to enter only odd numbers, else will raise an exception.

try:
    num = int(input("Enter an odd number: "))

    if num % 2 == 0:
        raise ValueError("Even number entered!")

    print("You entered a valid odd number:", num)

except ValueError as e:
    print("Error:", e)

finally:
    print("Execution completed")
